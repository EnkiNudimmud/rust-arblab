# %% [markdown]
# # Price Discovery (lead-lag sketch)

# %%
import numpy as np
x=np.cumsum(np.random.randn(1000)); y=np.roll(x,3)+np.random.randn(1000)*0.1
corr=np.corrcoef(x[:-3], y[3:])[0,1]
print('lead-lag corr (x leads):', corr)
